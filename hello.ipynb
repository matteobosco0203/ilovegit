# %%
hello hello hello
sfncbjdsK
# Out:
#   Cell In[2], line 1
#     hello hello hello
#           ^
# SyntaxError: invalid syntax

# %%
print("hello world")
# Out:
# hello world

# %%
hello hello hello
sfncbjdsK

# %%
hello hello hello
sfncbjdsK
