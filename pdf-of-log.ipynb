# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x=np.random.uniform(0.1,10,10000)

# %%
plt.hist(x, density=True, histtype="step")
# Out:
# (array([0.10658279, 0.10597663, 0.103552  , 0.09981403, 0.09799555,
#         0.10153147, 0.09860171, 0.09557092, 0.10021813, 0.10042018]),
#  array([0.10140981, 1.09125066, 2.08109152, 3.07093237, 4.06077322,
#         5.05061407, 6.04045493, 7.03029578, 8.02013663, 9.00997748,
#         9.99981834]),
#  [<matplotlib.patches.Polygon at 0x14ed3bacf50>])

# %%
y=np.log10(x)

# %%
plt.hist(y, density=True, histtype="step")
a=np.linspace(-1,1,100)
plt.plot(a,10**a*np.log(10)/(10-0.1))

# %%
mean_x=np.mean(x)
mean_y=np.mean(y)
median_x=np.median(x)
median_y=np.median(y)

# %%
print(np.log10(mean_x),mean_y)
print(np.log10(median_x),median_y)
# Out:
# 0.6976498344181759 0.5764669872221854
# 0.6960499009402509 0.6960498970916428
